# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.screener.in/company/HAL/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
#print(soup.prettify())

# %%
div = soup.find('div', {'class': 'responsive-holder fill-card-width'})
data = div.text
print(data)
# Out:
# Dec 2020
# Mar 2021
# Jun 2021
# Sep 2021
# Dec 2021
# Mar 2022
# Jun 2022
# Sep 2022
# Dec 2022
# Mar 2023
# Jun 2023
# Sep 2023
# Dec 2023
#
#
#
#
#
#
#                 Sales +
#
#
# 5,426
# 10,866
# 1,616
# 5,552
# 5,894
# 11,558
# 3,623
# 5,145
# 5,666
# 12,495
# 3,915
# 5,636
# 6,061
#
#
#
#
#                 Expenses +
#
#
# 4,217
# 8,155
# 1,372
# 4,309
# 4,463
# 9,063
# 2,798
# 3,535
# 4,680
# 9,252
# 3,036
# 4,107
# 4,627
#
#
#
#
#               Operating Profit
#
#
# 1,209
# 2,711
# 244
# 1,243
# 1,431
# 2,495
# 825
# 1,610
# 986
# 3,242
# 880
# 1,529
# 1,434
#
#
#
#
#               OPM %
#
#
# 22%
# 25%
# 15%
# 22%
# 24%
# 22%
# 23%
# 31%
# 17%
# 26%
# 22%
# 27%
# 24%
#
#
#
#
#                 Other Income +
#
#
# 92
# 133
# 150
# 138
# 195
# 503
# 192
# 261
# 497
# 722
# 411
# 471
# 460
#
#
#
#
#               Interest
#
#
# 53
# 30
# 15
# 1
# 1
# 42
# 0
# 0
# 2
# 55
# 0
# 0
# 0
#
#
#
#
#               Depreciation
#
#
# 179
# 648
# 111
# 243
# 373
# 382
# 208
# 252
# ...
