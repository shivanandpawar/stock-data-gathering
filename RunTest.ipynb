# %%
print("Executing Well")
# Out:
# Executing Well

# %%
# !ls
# Out:
# '1 - Retrieve Historical Stock Data.ipynb'   README.md
# '2 Data Aggregation.ipynb'		     RunTest.ipynb
# '3 Data Understanding.ipynb'		     TitanicModel.ipynb
# '4 Stock Forecasting.ipynb'		     Untitled.ipynb

# %%
print("Hey")
# Out:
# Hey

# %%
for i in range(1,1000):
    print("asdac")
# Out:
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# asdac
# ...
