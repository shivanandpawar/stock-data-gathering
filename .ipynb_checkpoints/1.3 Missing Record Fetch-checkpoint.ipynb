# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import timedelta
import json

# %%
def fetch_data(company_name):
    try:        
        msft = yf.Ticker(company_name)
        from datetime import datetime

        hist = msft.history(period="10mo")
        hist["Symbol_name"]=company_name
        hist["FinancialDate"]=pd.to_datetime(hist.index, format='%y-%m-%d').date
        return hist.loc[hist["FinancialDate"] == datetime.strptime("2022-12-26", '%Y-%m-%d').date() ]
    except Exception as e:
        print(e)
        return None

# %%
import time
import os

stock = pd.read_csv("/data/stock_symbols.csv")

skip_counter = 0

print(skip_counter)

counter = 0

df = fetch_data("LTIM.NS")

for ind in stock.index:
    print(stock['Symbol_New'][ind])
    counter = counter+1
    if counter < skip_counter:
        continue
    df_tmp = fetch_data(stock['Symbol_New'][ind])
    if df_tmp is not None:
        df = pd.concat([df, df_tmp])
    if counter % 5 == 0:
        df.to_csv("/data/missing_stock_data.csv", index=False)
    print(counter)
    time.sleep(10) 
    

df.to_csv("/data/missing_stock_data.csv", index=False)
# Out:
# Download

# %%
mdf = pd.read_csv("/data/missing_stock_data.csv")

# %%
rdf = pd.read_csv("/data/raw_stock_indicator.csv")

# %%
rdf.columns
# Out:
# Index(['Tax Effect Of Unusual Items', 'Tax Rate For Calcs',
#        'Normalized EBITDA', 'Total Unusual Items',
#        'Total Unusual Items Excluding Goodwill',
#        'Net Income From Continuing Operation Net Minority Interest',
#        'Reconciled Depreciation', 'Reconciled Cost Of Revenue', 'EBIT',
#        'Net Interest Income', 'Interest Expense', 'Normalized Income',
#        'Net Income From Continuing And Discontinued Operation',
#        'Total Expenses', 'Diluted Average Shares', 'Basic Average Shares',
#        'Diluted EPS', 'Basic EPS', 'Diluted NI Availto Com Stockholders',
#        'Net Income Common Stockholders', 'Otherunder Preferred Stock Dividend',
#        'Net Income', 'Minority Interests',
#        'Net Income Including Noncontrolling Interests',
#        'Net Income Continuous Operations', 'Tax Provision', 'Pretax Income',
#        'Other Non Operating Income Expenses', 'Special Income Charges',
#        'Restructuring And Mergern Acquisition',
#        'Net Non Operating Interest Income Expense',
#        'Interest Expense Non Operating', 'Operating Income',
#        'Operating Expense', 'Other Operating Expenses',
#        'Depreciation And Amortization In Income Statement',
#        'Depreciation Income Statement', 'Gross Profit', 'Cost Of Revenue',
#        'Total Revenue', 'Operating Revenue', 'FinancialDate', 'Year', 'Month',
#        'IsWeekend', 'FinancialDate_Adj', 'Open', 'High', 'Low', 'Close',
#        'Volume', 'Dividends', 'Stock Splits', 'Stock_Date', 'info_json',
#        'Adj Close', 'Interest Income', 'Interest Income Non Operating',
#        'Write Off', 'Selling General And Administration',
#        'General And Administrative Expense', 'Other Special Charges',
#        'Net Income Discontinuous Operations', 'Net Income Extraordinary',
#        'Impairment Of Capital Assets', 'Selling And Marketing Expense',
#        'Other Income Expense', 'Rent Expense Supplemental',
#        'Rent And Landing Fees', 'Research And Development',
#        'Total Operating Income As Reported', 'Capital Gains',
#        'Gain On Sale Of Security', 'Total Other Finance Cost',
#        'Gain On Sale Of Ppe', 'Earnings From Equity Interest',
#        'Depreciation Amortization Depletion Income Statement',
#        'Salaries And Wages', 'Average Dilution Earnings',
#        'Insurance And Claims', 'Amortization', 'Other Taxes', 'Other Gand A',
#        'Preferred Stock Dividends', 'Gain On Sale Of Business',
#        'Earnings From Equity Interest Net Of Tax'],
#       dtype='object')

# %%
rdf_b = rdf[rdf["Month"] == 12]
rdf_g = rdf[rdf["Month"] != 12]

# %%
rdf_g
# Out:
#       Tax Effect Of Unusual Items  Tax Rate For Calcs  Normalized EBITDA  \
# 0                    0.000000e+00            0.250000       1.767100e+10
# 1                    0.000000e+00            0.228569       1.795100e+10
# 3                    0.000000e+00            0.245756       1.051000e+10
# 4                    0.000000e+00            0.254524       9.749000e+09
# 5                    0.000000e+00            0.292948       1.731410e+08
# ...                           ...                 ...                ...
# 7309                 0.000000e+00            0.400000       1.915800e+07
# 7310                 0.000000e+00            0.400000       1.046100e+09
# 7311                -1.781540e+09            0.254881       2.010900e+09
# 7313                 0.000000e+00            0.268059      -1.310000e+07
# 7314                 2.638200e+09            0.230937       1.267500e+09
#
#       Total Unusual Items  Total Unusual Items Excluding Goodwill  \
# 0                     NaN                                     NaN
# 1            1.667000e+09                            1.667000e+09
# 3                     NaN                                     NaN
# 4                     NaN                                     NaN
# 5            0.000000e+00                            0.000000e+00
# ...                   ...                                     ...
# 7309         0.000000e+00                            0.000000e+00
# 7310         0.000000e+00                            0.000000e+00
# 7311        -6.989700e+09                           -6.989700e+09
# 7313                  NaN                                     NaN
# 7314         1.142390e+10                            1.142390e+10
#
#       Net Income From Continuing Operation Net Minority Interest  \
# 0                                          1.151500e+10
# 1                                          1.113700e+10
# 3                                          6.793000e+09
# 4                                          6.335000e+09
# 5                                          9.302400e+07
# ...                                                 ...
# 7309                                      -8.186000e+06
# 7310                                      -2.427000e+08
# 7311                                      -4.584000e+09
# 7313                                      -3.637000e+08
# 7314                                       9.174200e+09
#
#       Reconciled Depreciation  Reconciled Cost Of Revenue          EBIT  \
# 0                1.847000e+09                5.598700e+10  1.582400e+10
# 1                3.073000e+09                5.580700e+10  1.487800e+10
# 3                1.308000e+09                3.084900e+10  9.202000e+09
# 4                1.065000e+09                2.872300e+10  8.684000e+09
# 5                         NaN                9.829390e+08  1.731410e+08
# ...                       ...                         ...           ...
# 7309             1.913200e+07                1.767330e+08  2.600000e+04
# 7310             2.281000e+08                7.583900e+09  8.180000e+08
# 7311             2.125000e+08                8.704700e+09 -5.191300e+09
# 7313             1.725000e+08                3.871800e+09 -1.856000e+08
# 7314             1.767000e+08                9.425700e+09  1.251470e+10
#
#       Net Interest Income  ...  \
# 0            -460000000.0  ...
# 1            -436000000.0  ...
# 3            -189000000.0  ...
# 4            -174000000.0  ...
# 5             -41343000.0  ...
# ...                   ...  ...
# 7309           -3785000.0  ...
# 7310         -565100000.0  ...
# 7311         -535300000.0  ...
# 7313         -513500000.0  ...
# 7314         -449500000.0  ...
#
#       Depreciation Amortization Depletion Income Statement  \
# 0                                                   NaN
# 1                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 7309                                                NaN
# 7310                                                NaN
# 7311                                                NaN
# 7313                                                NaN
# 7314                                                NaN
#
#       Salaries And Wages  Average Dilution Earnings  Insurance And Claims  \
# 0                    NaN                        NaN                   NaN
# 1                    NaN                        NaN                   NaN
# 3                    NaN                        NaN                   NaN
# 4                    NaN                        NaN                   NaN
# 5                    NaN                        NaN                   NaN
# ...                  ...                        ...                   ...
# 7309                 NaN                        NaN                   NaN
# 7310                 NaN                        NaN                   NaN
# 7311                 NaN                        NaN                   NaN
# 7313                 NaN                        NaN                   NaN
# 7314                 NaN                        NaN                   NaN
#
#       Amortization  Other Taxes  Other Gand A  Preferred Stock Dividends  \
# 0              NaN          NaN           NaN                        NaN
# 1              NaN          NaN           NaN                        NaN
# 3              NaN          NaN           NaN                        NaN
# 4              NaN          NaN           NaN                        NaN
# 5              NaN          NaN           NaN                        NaN
# ...            ...          ...           ...                        ...
# 7309           NaN          NaN           NaN                        NaN
# 7310           NaN          NaN           NaN                        NaN
# 7311           NaN          NaN           NaN                        NaN
# 7313           NaN          NaN           NaN                        NaN
# 7314           NaN          NaN           NaN                        NaN
#
#       Gain On Sale Of Business  Earnings From Equity Interest Net Of Tax
# 0                          NaN                                       NaN
# 1                          NaN                                       NaN
# 3                          NaN                                       NaN
# 4                          NaN                                       NaN
# 5                          NaN                                       NaN
# ...                        ...                                       ...
# 7309                       NaN                                       NaN
# 7310                       NaN                                       NaN
# 7311                       NaN                                       NaN
# 7313                       NaN                                       NaN
# 7314                       NaN                                       NaN
#
# [5822 rows x 86 columns]
