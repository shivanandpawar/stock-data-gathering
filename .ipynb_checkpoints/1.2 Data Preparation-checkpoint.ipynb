# %%
import pandas as pd
import json

# %%
df = pd.read_csv("/data/raw_stock_ind.csv")

# %%
def json_parser(x):
    try:
        return json.loads(x)["symbol"]
    except Exception as e:
        print(e)
        return ""

# %%
df["company_symbol"] = df["info_json"].map(lambda x: json_parser(x))

# %%
df["company_symbol"].unique()
# Out:
# array(['LTIM.NS', '20MICRONS.NS', '21STCENMGM.NS', '3MINDIA.NS',
#        '3PLAND.NS', '5PAISA.NS', '63MOONS.NS', 'A2ZINFRA.NS', 'AAKASH.NS',
#        'AARON.NS', 'AARTIDRUGS.NS', 'AARTIIND.NS', 'AARVEEDEN.NS',
#        'AARVI.NS', 'AAVAS.NS', 'ABAN.NS', 'ABB.NS', 'POWERINDIA.NS',
#        'ACC.NS', 'ACCELYA.NS', 'ACCURACY.NS', 'ACEINTEG.NS'], dtype=object)

# %%
df
# Out:
#      Tax Effect Of Unusual Items  Tax Rate For Calcs  Normalized EBITDA  \
# 0                   0.000000e+00            0.250000       1.767100e+10
# 1                   0.000000e+00            0.228569       1.795100e+10
# 2                  -1.182283e+08            0.236457       1.576600e+10
# 3                   0.000000e+00            0.245756       1.051000e+10
# 4                   0.000000e+00            0.254524       9.749000e+09
# ..                           ...                 ...                ...
# 163                 0.000000e+00            0.258461       7.035600e+07
# 164                 0.000000e+00            0.240678       1.514480e+08
# 165                 0.000000e+00            0.257756       1.248710e+08
# 166                 0.000000e+00            0.312072       3.851200e+07
# 167                 0.000000e+00            0.251384       9.669500e+07
#
#      Total Unusual Items  Total Unusual Items Excluding Goodwill  \
# 0                    NaN                                     NaN
# 1           1.667000e+09                            1.667000e+09
# 2          -5.000000e+08                           -5.000000e+08
# 3                    NaN                                     NaN
# 4                    NaN                                     NaN
# ..                   ...                                     ...
# 163         0.000000e+00                            0.000000e+00
# 164         0.000000e+00                            0.000000e+00
# 165         0.000000e+00                            0.000000e+00
# 166         0.000000e+00                            0.000000e+00
# 167         0.000000e+00                            0.000000e+00
#
#      Net Income From Continuing Operation Net Minority Interest  \
# 0                                         1.151500e+10
# 1                                         1.113700e+10
# 2                                         1.000500e+10
# 3                                         6.793000e+09
# 4                                         6.335000e+09
# ..                                                 ...
# 163                                       4.609700e+07
# 164                                       1.093180e+08
# 165                                       8.749800e+07
# 166                                       2.177500e+07
# 167                                       6.745700e+07
#
#      Reconciled Depreciation  Reconciled Cost Of Revenue          EBIT  \
# 0               1.847000e+09                5.598700e+10  1.582400e+10
# 1               3.073000e+09                5.580700e+10  1.487800e+10
# 2               1.781000e+09                5.472200e+10  1.348500e+10
# 3               1.308000e+09                3.084900e+10  9.202000e+09
# 4               1.065000e+09                2.872300e+10  8.684000e+09
# ..                       ...                         ...           ...
# 163             7.922000e+06                8.946900e+07  6.243400e+07
# 164             7.017000e+06                8.549400e+07  1.444310e+08
# 165             6.433000e+06                9.268400e+07  1.184380e+08
# 166             6.405000e+06                6.450700e+07  3.210700e+07
# 167             6.417000e+06                7.074500e+07  9.027800e+07
#
#      Net Interest Income  ...  General And Administrative Expense  \
# 0           -460000000.0  ...                                 NaN
# 1           -436000000.0  ...                                 NaN
# 2           -379000000.0  ...                                 NaN
# 3           -189000000.0  ...                                 NaN
# 4           -174000000.0  ...                                 NaN
# ..                   ...  ...                                 ...
# 163            -270000.0  ...                                 NaN
# 164            -463000.0  ...                                 NaN
# 165            -555000.0  ...                                 NaN
# 166            -454000.0  ...                                 NaN
# 167            -169000.0  ...                                 NaN
#
#      Other Special Charges  Net Income Discontinuous Operations  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                  NaN
# 3                      NaN                                  NaN
# 4                      NaN                                  NaN
# ..                     ...                                  ...
# 163                    NaN                                  NaN
# 164                    NaN                                  NaN
# 165                    NaN                                  NaN
# 166                    NaN                                  NaN
# 167                    NaN                                  NaN
#
#      Net Income Extraordinary  Impairment Of Capital Assets  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# ..                        ...                           ...
# 163                       NaN                           NaN
# 164                       NaN                           NaN
# 165                       NaN                           NaN
# 166                       NaN                           NaN
# 167                       NaN                           NaN
#
#      Selling And Marketing Expense  Other Income Expense  \
# 0                              NaN                   NaN
# 1                              NaN                   NaN
# 2                              NaN                   NaN
# 3                              NaN                   NaN
# 4                              NaN                   NaN
# ..                             ...                   ...
# 163                            NaN                   NaN
# 164                            NaN                   NaN
# 165                            NaN                   NaN
# 166                            NaN                   NaN
# 167                            NaN                   NaN
#
#      Rent Expense Supplemental  Rent And Landing Fees  company_symbol
# 0                          NaN                    NaN         LTIM.NS
# 1                          NaN                    NaN         LTIM.NS
# 2                          NaN                    NaN         LTIM.NS
# 3                          NaN                    NaN         LTIM.NS
# 4                          NaN                    NaN         LTIM.NS
# ..                         ...                    ...             ...
# 163                        NaN                    NaN   ADVANIHOTR.NS
# 164                        NaN                    NaN   ADVANIHOTR.NS
# 165                        NaN                    NaN   ADVANIHOTR.NS
# 166                        NaN                    NaN   ADVANIHOTR.NS
# 167                        NaN                    NaN   ADVANIHOTR.NS
#
# [168 rows x 70 columns]
