# %%
import requests

# Set up the API endpoint URL and the bearer token
url = "https://qa.refract-fosfor.com/mosaic-console-backend/secured/api/project/v1"
token = "eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJ4WTdTd3k5UE1xaXRDQmNSMm5qcVl6bmoxS3NqZzV3TmdOV0xDVzdyUkhvIn0.....N_8rdbJ591jZoqWXLAuGQHjltX7KWFnkOKFXVd7vWHXxgHFd-dU0LbOMco3Ro-T46cBhSAzEgcai2oSlaujL6DGmv2MjIXEbCZAKjI905qBjDAuoX0JO0VAqb3OyHYp7n4EACMwS8fXRiBWP90byZbFeEa-xOl5BMfh4nnRu5HCnp7-oTinsPkaihTvZP0BRhIG7kspahn3boXvHV-2yrDzQl49tuHhRvtEBgG0hLMJ-YXJlre3SvgAN-sIfyRgvcgGZp2zt8Qt3ZAua2FJk8g5faqhkwO1zyq0lVLCW1pn2DSqrLiz0y4iNCoW8FVriANr_40VBRV4MJ3CM95XitA"

# %%
sess = requests.Session()
# Send the GET request with the bearer token and SSL encryption
response = sess.get(url, headers={"Authorization": f"Bearer {token}"}, verify=False)

# Check the response status code
if response.status_code == 200:
    print("Successful response from API!")
else:
    print("Failed to retrieve data from API.")
# Out:
# /tmp/pip_packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'qa.refract-fosfor.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Successful response from API!

# %%
response.text
# Out:
# '[{"id":"7c2f23f6-88d4-479c-8997-2149ce8dad3c","createdBy":"refract.admin","createdDate":"2023-06-15T13:36:56.505+00:00","updatedBy":"refract.admin","updatedDate":"2023-06-15T13:36:56.505+00:00","projectName":"postgres-refractio-test","description":"test","status":"ACTIVE","type":"string","accessType":"OWNER","resourceQuota":"5GB","groupenv":null,"modelType":null,"dataSourceCount":0,"flowsCount":0,"streamCount":0,"notebookCount":0,"jobCount":0,"modelCount":0,"workFlowCount":0,"userName":"Refract Admin","defaultRepoFlag":null},{"id":"02004161-e4a5-46ac-a77c-a446be0e81cf","createdBy":"refract.admin","createdDate":"2023-06-22T08:13:11.371+00:00","updatedBy":"refract.admin","updatedDate":"2023-06-22T08:13:11.371+00:00","projectName":"Project_List_Test","description":"Project_List_Test","status":"ACTIVE","type":"string","accessType":"OWNER","resourceQuota":"5GB","groupenv":null,"modelType":null,"dataSourceCount":0,"flowsCount":0,"streamCount":0,"notebookCount":0,"jobCount":0,"modelCount":
# ...

# %%
# !pip freeze | grep jupyter
# Out:
# jupyter-client==8.3.0
# jupyter-core==5.3.1
# jupyter-server==2.0.0a1
# jupyter-server-terminals==0.4.4
# jupyter-telemetry==0.1.0
# jupyterhub==1.5.0
# jupyterlab==3.2.4
# jupyterlab-pygments==0.2.2
# jupyterlab-server==2.23.0
# jupyterlab-widgets==3.0.8
